# %%
import xarray
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Visualize Merged Xarray

# %%
date = '2005-08-05'

merged_xr = xarray.open_dataset(f'../data/merged_inputs/{date}_with_imputation.nc')

merged_xr
# Out:
# <xarray.Dataset>
# Dimensions:          (band: 1, x: 7200, y: 3601)
# Coordinates:
#   * band             (band) int64 1
#   * x                (x) float64 -1.112e+07 -1.112e+07 ... -4.449e+06 -4.448e+06
#   * y                (y) float64 5.559e+06 5.558e+06 ... 2.224e+06 2.223e+06
# Data variables: (12/26)
#     aod_047          (y, x) float32 ...
#     aod_055          (y, x) float32 ...
#     aod_buffer_047   (y, x) float32 ...
#     aod_buffer_055   (y, x) float32 ...
#     avg_pm25         (y, x) float32 ...
#     day_cos          (y, x) float32 ...
#     ...               ...
#     knnidw_pm25_val  (y, x) float32 ...
#     month_cos        (y, x) float32 ...
#     month_sin        (y, x) float32 ...
#     ndvi             (y, x) float32 ...
#     wildfire_smoke   (y, x) float32 ...
#     year             (y, x) float32 ...

# %%
f, ax1 = plt.subplots(1, 1, figsize=(12, 6))

# The first plot (in kelvins) chooses "viridis" and uses the data's min/max
merged_xr['aod_047'].plot(ax=ax1, 
                          cbar_kwargs={"label": "Var"},
#                           vmin=0, vmax=35
                         )
ax1.set_title(f"Var - {date}")
# Out:
# Text(0.5, 1.0, 'Var - 2005-08-05')

# %%
f, ax1 = plt.subplots(1, 1, figsize=(12, 6))

# The first plot (in kelvins) chooses "viridis" and uses the data's min/max
(merged_xr['aod_047'].notnull()).plot(ax=ax1, 
                          cbar_kwargs={"label": "Var"},
#                           vmin=0, vmax=35
                         )
ax1.set_title(f"Var - {date}")
# Out:
# Text(0.5, 1.0, 'Var - 2005-08-05')

# %%
f, ax1 = plt.subplots(1, 1, figsize=(12, 6))

# The first plot (in kelvins) chooses "viridis" and uses the data's min/max
(merged_xr['daymet_tmax'].notnull()).plot(ax=ax1, 
                          cbar_kwargs={"label": "Var"},
#                           vmin=0, vmax=35
                         )
ax1.set_title(f"Var - {date}")
# Out:
# Text(0.5, 1.0, 'Var - 2021-07-01')

# %%
f, ax1 = plt.subplots(1, 1, figsize=(12, 6))

# The first plot (in kelvins) chooses "viridis" and uses the data's min/max
(merged_xr['aod_047'].notnull() & merged_xr['gridmet_vs'].notnull()).plot(ax=ax1, 
                          cbar_kwargs={"label": "Var"},
#                           vmin=0, vmax=35
                         )
ax1.set_title(f"Var - {date}")
# Out:
# Text(0.5, 1.0, 'Var - 2005-08-05')
